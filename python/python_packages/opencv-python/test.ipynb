# %%
import cv2
import os
import math
import glob

# %%
original_path = '/Users/jeonghyunkim/dev/pencil_sample/'
filename = 'hb_pencil_61m.mp4'
save_path='/Users/jeonghyunkim/dev/test/' 
resize_rate = 2

# %%
video_paths = glob.glob(original_path+"/*.mp4") + glob.glob(original_path+"/*.mov")
video_paths
# Out:
# ['/Users/jeonghyunkim/dev/pencil_sample/hb_pencil_61m.mp4']

# %%
video_capture = cv2.VideoCapture(original_path+filename)
fps = int(video_capture.get(cv2.CAP_PROP_FPS))
old_frame_count = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))

# %%
old_frame_count * resize_rate
# Out:
# 2478

# %%
# reduce video frame
def change_frame_rate(original_path, filename, save_path, frame_rate):
    old_vid = os.path.join(original_path, filename)
    new_vid = os.path.join(save_path, filename)

    video_capture = cv2.VideoCapture(old_vid)
    old_fps = int(video_capture.get(cv2.CAP_PROP_FPS))
    new_fps = round(old_fps*frame_rate)
    frame_count = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    
    if not video_capture.isOpened():
        print("Video Capture cannot be opened.")
        return
    else:
        print(f"original fps : {old_fps}, new fps : {new_fps}, frame_count : {frame_count}")
    video_codec = cv2.VideoWriter_fourcc(*'avc1')
    retval, video_frame = video_capture.read()
    if video_frame is not None:
        video_writer = cv2.VideoWriter(new_vid, video_codec, new_fps, (video_frame.shape[1], video_frame.shape[0]))
        frame_index = 0
        #print("frame_index is not None")

        while video_capture.isOpened():
            if frame_index == frame_count:
                break
            retval, frame = video_capture.read()
            if not retval:
                break
            video_writer.write(frame)
            frame_index += 1

        if video_writer.isOpened():
            video_writer.release()
        video_capture.release()
        return new_vid

# %%
change_frame_rate(original_path, filename, save_path, resize_rate)
# Out:
# original fps : 29, reduced fps : 58, frame_count : 1239
# '/Users/jeonghyunkim/dev/test/hb_pencil_61m.mp4'

# %%
# video2image
vidcap = cv2.VideoCapture('/Users/jeonghyunkim/Downloads/A506_FMS_3_0_4.mp4')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("/Users/jeonghyunkim/Downloads/path_output_frame2/%06d.jpg" % count, image)     # save frame as JPEG file
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1

print("finish! convert video to frame")
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# Python program to resize frame's
# from video with aspect ratio

# Import the libraries
import cv2

# Define a video capture object
vidcap = cv2.VideoCapture("/Users/jeonghyunkim/Downloads/A506_FMS_3_0_4.mp4")

# Capture video frame by frame
success, image = vidcap.read()

# Declare the variable with value 0
count = 0

# Creating a loop for running the video
# and saving all the frames
while success:

	# Capture video frame by frame
	success, image = vidcap.read()

	# Resize the image frames
	resize = cv2.resize(image, (700, 500))

	# Saving the frames with certain names
	cv2.imwrite("/Users/jeonghyunkim/Downloads/test/%04d.jpg" % count, resize)

	# Closing the video by Escape button
	if cv2.waitKey(10) == 27:
		break

	# Incrementing the variable value by 1
	count += 1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [12], line 24
#      21 success, image = vidcap.read()
#      23 # Resize the image frames
# ---> 24 resize = cv2.resize(image, (700, 500))
#      26 # Saving the frames with certain names
#      27 cv2.imwrite("/Users/jeonghyunkim/Downloads/test/%04d.jpg" % count, resize)
#
# error: OpenCV(4.6.0) /Users/xperience/actions-runner/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
# 동영상 크기 변환
vidcap.set(cv2.CAP_PROP_FRAME_WIDTH, w/2) # 가로
vidcap.set(cv2.CAP_PROP_FRAME_HEIGHT, h/2) # 세로
# Out:
# False

# %%
# 변환된 동영상 크기 정보
w = vidcap.get(cv2.CAP_PROP_FRAME_WIDTH)
h = vidcap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("변환된 동영상 너비(가로) : {}, 높이(세로) : {}".format(w, h))
# Out:
# 변환된 동영상 너비(가로) : 1314.0, 높이(세로) : 986.0
